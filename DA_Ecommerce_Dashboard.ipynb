# %% [markdown]
# # **ANALYSIS DATA PROJECT : E-COMMERCE PUBLIC DATASET**

# %% [markdown]
# * Name         : Lintang Nagari
# * Email        : unggullintangg@gmail.com
# * Linkedin     : <a href='https://www.linkedin.com/in/lintangnagari/'>Lintang Nagari</a>
# * Github       : <a href='https://github.com/lnt-ngr'>lnt-ngr</a>

# %% [markdown]
# # **BUSINESS QUESTION**

# %% [markdown]
# **Specifict:**
# * Categories of Products That Sell Well and Those That Sell Poorly Based on the Number Sold
# * Categories of Products with the Highest Average Review Scores
# * Customer Expenditure in the Last Three Months
#
# **Measurable:**
# * Calculate How Often Customers Purchased in the Last Six Months
#
# **Action-oriented:**
# * Collect and Analyze Demographic Data to Tailor Marketing Efforts and Product Offerings
#
# **Relevant:**
# * Total Revenue is Key to Financial Stability and Growth
#
# **Time-bound:**
# * Calculate Total Revenue in the Last Three Months by the End of This Week

# %% [markdown]
# ## **Library untuk Data Analysis**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Data Wrangling**

# %% [markdown]
# ### **> Gathering Data**

# %%
customer_df = pd.read_csv('./dataset/customers_dataset.csv')
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv('./dataset/geolocation_dataset.csv')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv('./dataset/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_payments_df = pd.read_csv('./dataset/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv('./dataset/order_reviews_dataset.csv')
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
orders_df = pd.read_csv('./dataset/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
product_category_name_df = pd.read_csv('./dataset/product_category_name_translation.csv')
product_category_name_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv('./dataset/products_dataset.csv')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
sellers_df = pd.read_csv('./dataset/sellers_dataset.csv')
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### **> Assessing Data**

# %% [markdown]
# #### **1. customer_df**

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# (✓) In the data above, everything runs smoothly! There are no strange issues to worry about. All data types are appropriate and correct.

# %%
# To calculate the number of missing values in a dataset
customer_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# (✓) In the data above, there are no missing values.

# %%
# To calculate the total number of duplicate rows in a dataset
print(f'The total number of duplications: {customer_df.duplicated().sum()}')
# Out:
# The total number of duplications: 0

# %% [markdown]
# (✓) In the data above, there are no duplicate rows.

# %%
# To view the statistical parameters of a dataset
customer_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# (✓) In the data above, there are no anomalies in the statistical parameters.

# %%
customer_df.sample(10)
# Out:
#                             customer_id                customer_unique_id  \
# 43185  553e559297fac7c84f187bdf0867ba57  c45794a47dc0b5553f1c341a23ebef14
# 13808  6cc2669297113f79b91a3904a83c2da9  f71f43f5a8dc56beb6ebdabf0d82e802
# 92599  2b0bd5eca653853a14cd538cc974a7d0  0fc594155e889688ea4477afcd26a134
# 81818  583483c4d60ab300ed89f4c905bba728  68c7baafa6c7f52df24fdd9c0e24318a
# 19871  cd0dbdf1e0c62296278fbf3133949247  eb99009d1598d945ae06b4e5f761cd8a
# 23624  e5583a36cc70b95b339afc5d67c5efa2  c1b1eb8a5a67819956718ddddcf038e6
# 43875  6ae108a103903506b207a3168689f13b  93db776631b272d7fca708fe4eb790ca
# 58055  895bbb0f6027aa8b3a841fdb10711dce  c9027dd7aa244d174bd29a92e9e181cf
# 33543  e15daad9efaafb0d4d10043c9ca77e7b  a1b3368fc2fbaee34a19608fc1eb4a4b
# 34166  fb11202eb711bfb022738e48d945e80d  e98d34eecb9603fddcd5096307957246
#
#        customer_zip_code_prefix            customer_city customer_state
# 43185                     75813                     cacu             GO
# 13808                      6364              carapicuiba             SP
# 92599                     45653                   ilheus             BA
# 81818                     18900  santa cruz do rio pardo             SP
# 19871                     49000                  aracaju             SE
# 23624                      8715          mogi das cruzes             SP
# 43875                     22070           rio de janeiro             RJ
# 58055                     38702           patos de minas             MG
# 33543                     87083                  maringa             PR
# 34166                      2256                sao paulo             SP

# %% [markdown]
# #### **2. order_items_df**

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# There is nothing strange in the data above, but there is a data type error in the `shipping_limit_date` column. However, it seems we won't be using that column for any analysis

# %%
# To calculate the number of missing values in a dataset
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# (✓) In the data above, there are no missing values (missing values).

# %%
# To calculate the total number of duplicate rows in a dataset
print(f'The total number of duplications: {order_items_df.duplicated().sum()}')
# Out:
# The total number of duplications: 0

# %% [markdown]
# (✓) In the data above, there are no duplicate rows.

# %%
# To view the statistical parameters of a dataset
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# (✓) In the data above, there are no anomalies in the statistical parameters.

# %% [markdown]
# #### **3. order_payments_df**

# %%
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# (✓) In the data above, there is nothing unusual with the data.

# %%
# Untuk menghitung jumlah nilai yang hilang dalam sebuah kumpulan data
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# (✓) In the data above, there are no missing values.

# %%
# To calculate the total number of duplicate rows in a dataset
print(f'The total number of duplications: {order_payments_df.duplicated().sum()}')
# Out:
# The total number of duplications: 0

# %% [markdown]
# (✓) In the data above, there are no duplicate rows.

# %%
# To view the statistical parameters of a dataset
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# (✓) In the data above, there are no anomalies in the statistical parameters.

# %% [markdown]
# #### **4. order_reviews_df**

# %%
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# There are no anomalies in the data above. All data types are correct. Some columns, such as `review_comment_title` and `review_comment_message`, have missing values. This may occur because not everyone who provides a rating (1-5) will also leave a written review.

# %%
# To calculate the number of missing values in a dataset
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# As I mentioned before, not everyone who provides a `review_score` will leave a written comment in `review_comment_title` and `review_comment_message`.

# %%
# To calculate the total number of duplicate rows in a dataset
print(f'The total number of duplications: {order_reviews_df.duplicated().sum()}')
# Out:
# The total number of duplications: 0

# %% [markdown]
# (✓) In the data above, there are no duplicate rows.

# %%
# To view the statistical parameters of a dataset
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# #### **5. orders_df**

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Kesalahan tipe data terdapat pada kolom-kolom berikut: `order_delivered_carrier_date`, `order_delivered_customer_date`, `order_purchase_timestamp`, dan `order_approved_at`. Kolom-kolom ini seharusnya dikategorikan sebagai tipe data `datetime`, bukan `object`.

# %%
# To calculate the number of missing values in a dataset
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Some columns contain missing values, but we won't be using them to answer our business questions.

# %%
# To calculate the total number of duplicate rows in a dataset
print(f'The total number of duplications: {orders_df.duplicated().sum()}')
# Out:
# The total number of duplications: 0

# %% [markdown]
# (✓) In the data above, there are no duplicate rows.

# %%
# Untuk melihat parameter statistik dari sebuah kumpulan data (dataset)
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-08 23:38:46
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %% [markdown]
# #### **6. product_category_name_df**

# %%
product_category_name_df
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %% [markdown]
# #### **7. product_df**

# %%
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
# To calculate the number of missing values in a dataset
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# There are several columns with missing values.

# %%
# To calculate the total number of duplicate rows in a dataset
print(f'The total number of duplications: {products_df.duplicated().sum()}')
# Out:
# The total number of duplications: 0

# %% [markdown]
# (✓) In the data above, there are no duplicate rows.

# %% [markdown]
# #### **8. sellers_df**

# %%
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
# To calculate the number of missing values in a dataset
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
# To calculate the total number of duplicate rows in a dataset
print(f'The total number of duplications: {sellers_df.duplicated().sum()}')
# Out:
# The total number of duplications: 0

# %% [markdown]
# ### **> Cleaning Data**

# %% [markdown]
# Here's the translation in the same format:
#
# 1. In the `orders_df`, there is a data type error in `order_delivered_customer_date`, `order_delivered_carrier_date`, `order_approved_at`, and `order_purchase_timestamp`, which are currently of type `object` and should be `datetime`.
#
# 2. In the `products_df`, there are several columns with missing values.
#
# 3. There are null values in the `order_approved_at` column, causing it to be treated as a float value. Therefore, it cannot be used for RFM analysis.

# %% [markdown]
# #### **1. First Data Cleaning Task**

# %%
# To access the columns that will be modified
datetime_columns = ['order_estimated_delivery_date','order_delivered_carrier_date', 'order_delivered_customer_date', 'order_approved_at', 'order_purchase_timestamp']

# To convert the previously accessed columns to datetime data type
for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
# To change the timestamp format in the `order_approved_at` column
orders_df['order_approved_at'] = orders_df['order_approved_at'].dt.strftime('%Y-%m-%d')
orders_df['order_approved_at'] = pd.to_datetime(orders_df['order_approved_at'])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# #### **2. Second Data Cleaning Task**

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# 128                    NaN                         NaN                 NaN
# 145                    NaN                         NaN                 NaN
# 154                    NaN                         NaN                 NaN
# 197                    NaN                         NaN                 NaN
# ...                    ...                         ...                 ...
# 32515                  NaN                         NaN                 NaN
# 32589                  NaN                         NaN                 NaN
# 32616                  NaN                         NaN                 NaN
# 32772                  NaN                         NaN                 NaN
# 32852                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 105               650.0               17.0               14.0
# 128               300.0               16.0                7.0
# 145               200.0               20.0               20.0
# 154             18500.0               41.0               30.0
# 197               300.0               35.0                7.0
# ...                 ...                ...                ...
# 32515            1800.0               30.0               20.0
# 32589             800.0               30.0               10.0
# 32616             200.0               21.0                8.0
# 32772            1300.0               45.0               16.0
# 32852             700.0               28.0                3.0
#
#        product_width_cm
# 105                12.0
# 128                20.0
# 145                20.0
# 154                41.0
# 197                12.0
# ...                 ...
# 32515              70.0
# 32589              23.0
# 32616              16.0
# 32772              45.0
# 32852              43.0
#
# [610 rows x 9 columns]

# %%
products_df[products_df.product_weight_g.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %% [markdown]
# Less is more. Let's declutter and simplify.

# %%
products_df.dropna(inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# #### **3. Third Data Cleaning Task**

# %%
# Filling missing values in 'order_approved_at' with the earliest available date.
min_date = orders_df['order_approved_at'].min()
orders_df['order_approved_at'].fillna(min_date, inplace=True)
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                   0
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **1. Explore customer_df**

# %%
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customer_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN

# %%
# Demographics based on place of residence (city)
customer_df.groupby('customer_city').customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
# Total kota di Brazil
print(f'The total number of cities in Brazil in this dataset is {customer_df.customer_city.nunique()}')
# Out:
# The total number of cities in Brazil in this dataset is 4119

# %% [markdown]
# The majority of buyers come from the cities of `Sao Paulo` and `Rio de Janeiro`

# %%
# Demographics based on state
customer_df.groupby('customer_state').customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# Most of our customers from the state of `SP` or `Sao Paulo`

# %% [markdown]
# ### **2, Explore order_items_df**

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_items_df.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# top     aca2eb7d00ea1a7b8ebd4e68314663af  6560211a19b47992c3666cc44a7e94c0
# freq                                 527                              2033
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         shipping_limit_date          price  freight_value
# count                112650  112650.000000  112650.000000
# unique                93318            NaN            NaN
# top     2017-07-21 18:25:23            NaN            NaN
# freq                     21            NaN            NaN
# mean                    NaN     120.653739      19.990320
# std                     NaN     183.633928      15.806405
# min                     NaN       0.850000       0.000000
# 25%                     NaN      39.900000      13.080000
# 50%                     NaN      74.990000      16.260000
# 75%                     NaN     134.900000      21.150000
# max                     NaN    6735.000000     409.680000

# %% [markdown]
# The smallest purchase is at `$ 0.85`, while the largest goes up to `$ 6735`.

# %% [markdown]
# ### **3. Explore order_payments_df**

# %%
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments_df.groupby('payment_type').order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# The majority of buyers prefer to make their payments using `credit cards`.

# %% [markdown]
# ### **4. Explore order_reviews_df**

# %%
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
order_reviews_df.describe(include='all')
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# count   99224.000000                11568                  40977
# unique           NaN                 4527                  36159
# top              NaN            Recomendo              Muito bom
# freq             NaN                  423                    230
# mean        4.086421                  NaN                    NaN
# std         1.347579                  NaN                    NaN
# min         1.000000                  NaN                    NaN
# 25%         4.000000                  NaN                    NaN
# 50%         5.000000                  NaN                    NaN
# 75%         5.000000                  NaN                    NaN
# max         5.000000                  NaN                    NaN
#
#        review_creation_date review_answer_timestamp
# count                 99224                   99224
# unique                  636                   98248
# top     2017-12-19 00:00:00     2017-06-15 23:21:05
# freq                    463                       4
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# max                     NaN                     NaN

# %% [markdown]
# With an average `review score` of `4.086` and a standard deviation of `1.347`, it appears that overall users are quite satisfied with the products they purchase.

# %%
order_reviews_df.groupby('review_score').order_id.nunique().sort_values(ascending=False)
# Out:
# review_score
# 5    57076
# 4    19098
# 1    11393
# 3     8160
# 2     3148
# Name: order_id, dtype: int64

# %% [markdown]
# As seen above, the majority of users are satisfied with the products they purchase.

# %%
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# ### **5. Explore sellers_df**

# %%
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
# Seller Demographics by City
sellers_df.groupby('seller_city').seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %%
# Seller Demographics by state
sellers_df.groupby('seller_state').seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_id, dtype: int64

# %% [markdown]
# ### **6. Explore products_df dan order_items_df**

# %%
product_count_df = pd.merge(
    left = order_items_df,
    right = products_df,
    how = 'left',
    left_on = 'product_id',
    right_on = 'product_id'
)

product_count_english_df = pd.merge(
    left = product_count_df,
    right = product_category_name_df,
    how = 'left',
    left_on = 'product_category_name',
    right_on = 'product_category_name'
)

product_count_english_df.rename(columns={
    'order_id': 'total_order'
}, inplace=True)

product_count_english_df.groupby('product_category_name_english').total_order.nunique().sort_values(ascending=False).reset_index()
# Out:
#    product_category_name_english  total_order
# 0                 bed_bath_table         9417
# 1                  health_beauty         8836
# 2                 sports_leisure         7720
# 3          computers_accessories         6689
# 4                furniture_decor         6449
# ..                           ...          ...
# 66         arts_and_craftmanship           23
# 67                    la_cuisine           13
# 68             cds_dvds_musicals           12
# 69     fashion_childrens_clothes            8
# 70         security_and_services            2
#
# [71 rows x 2 columns]

# %% [markdown]
# **<I>The top 5 successful products are:</I>**
#
# 1. `bed_bath_table`
# 2. `health_beauty`
# 3. `sports_leisure`
# 4. `computers_accessories`
# 5. `furniture_decor`

# %% [markdown]
# ### **7. Explore order_payments_df dan orders_df**

# %%
total_revenue_df = pd.merge(
    left = orders_df,
    right = order_payments_df,
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)
total_revenue_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered      2017-10-02 10:56:33        2017-10-02
# 1    delivered      2017-10-02 10:56:33        2017-10-02
# 2    delivered      2017-10-02 10:56:33        2017-10-02
# 3    delivered      2018-07-24 20:41:37        2018-07-26
# 4    delivered      2018-08-08 08:38:49        2018-08-08
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  payment_sequential payment_type  \
# 0                    2017-10-18                 1.0  credit_card
# 1                    2017-10-18                 3.0      voucher
# 2                    2017-10-18                 2.0      voucher
# 3                    2018-08-13                 1.0       boleto
# 4                    2018-09-04                 1.0  credit_card
#
#    payment_installments  payment_value
# 0                   1.0          18.12
# 1                   1.0           2.00
# 2                   1.0          18.59
# 3                   1.0         141.46
# 4                   3.0         179.12

# %%
revenue_by_day_df = total_revenue_df.groupby('order_approved_at').agg({
    'order_id': 'nunique',
    'payment_value': 'sum'
})
revenue_by_day_df.rename(columns={
    'order_id': 'total_order',
    'payment_value': 'total_revenue'
}, inplace=True)

revenue_by_day_df.reset_index(inplace=True)
revenue_by_day_df['order_approved_at'] = pd.to_datetime(revenue_by_day_df['order_approved_at'])

# Removing the last one as there was only one transaction in that month
last_month = revenue_by_day_df['order_approved_at'].max()
months_to_remove = (revenue_by_day_df['order_approved_at'] == last_month)
revenue_by_day_df = revenue_by_day_df[~months_to_remove]

revenue_by_day_df
# Out:
#     order_approved_at  total_order  total_revenue
# 0          2016-09-15          161       37129.77
# 1          2016-10-04           20        2877.21
# 2          2016-10-05           11        2356.44
# 3          2016-10-06          110       20145.72
# 4          2016-10-07           59       12185.05
# ..                ...          ...            ...
# 605        2018-08-25           81       10510.08
# 606        2018-08-26           70       11478.95
# 607        2018-08-27           64        6447.78
# 608        2018-08-28           56        5738.28
# 609        2018-08-29           15        2298.71
#
# [610 rows x 3 columns]

# %% [markdown]
# ### **8. Explore order_reviews_df, order_items_df, dan products_df**

# %%
order_items_reviews_df = pd.merge(
    left = order_reviews_df,
    right = order_items_df,
    how = 'left',
    left_on = 'order_id',
    right_on = 'order_id'
)

# %%
items_in_english_df = pd.merge(
    left = products_df,
    right = product_category_name_df,
    how = 'left',
    left_on = 'product_category_name',
    right_on = 'product_category_name'
)

# %%
order_items_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
#
#    review_score review_comment_title                 review_comment_message  \
# 0             4                  NaN                                    NaN
# 1             4                  NaN                                    NaN
# 2             5                  NaN                                    NaN
# 3             5                  NaN                                    NaN
# 4             5                  NaN  Recebi bem antes do prazo estipulado.
#
#   review_creation_date review_answer_timestamp  order_item_id  \
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59            1.0
# 1  2018-01-18 00:00:00     2018-01-18 21:46:59            2.0
# 2  2018-03-10 00:00:00     2018-03-11 03:05:13            1.0
# 3  2018-02-17 00:00:00     2018-02-18 14:36:24            1.0
# 4  2017-04-21 00:00:00     2017-04-21 22:02:06            1.0
#
#                          product_id                         seller_id  \
# 0  fd25ab760bfbba13c198fa3b4f1a0cd3  6d803cb79cc31c41c4c789a75933b3c7
# 1  fd25ab760bfbba13c198fa3b4f1a0cd3  6d803cb79cc31c41c4c789a75933b3c7
# 2  be0dbdc3d67d55727a65d4cd696ca73c  8e6d7754bc7e0f22c96d255ebda59eba
# 3  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 4  52c80cedd4e90108bf4fa6a206ef6b03  a1043bafd471dff536d0c462352beb48
#
#    shipping_limit_date   price  freight_value
# 0  2018-01-18 15:47:59  185.00          13.63
# 1  2018-01-18 15:47:59  185.00          13.63
# 2  2018-03-06 12:48:39   79.79           8.30
# 3  2018-02-08 10:31:15  149.00          45.12
# 4  2017-04-13 17:55:19  179.99          42.85

# %%
items_in_english_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %%
review_df = pd.merge(
    left = order_items_reviews_df,
    right = items_in_english_df,
    how = 'left',
    left_on = 'product_id',
    right_on = 'product_id'
)

# %%
review_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
#
#    review_score review_comment_title                 review_comment_message  \
# 0             4                  NaN                                    NaN
# 1             4                  NaN                                    NaN
# 2             5                  NaN                                    NaN
# 3             5                  NaN                                    NaN
# 4             5                  NaN  Recebi bem antes do prazo estipulado.
#
#   review_creation_date review_answer_timestamp  order_item_id  \
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59            1.0
# 1  2018-01-18 00:00:00     2018-01-18 21:46:59            2.0
# 2  2018-03-10 00:00:00     2018-03-11 03:05:13            1.0
# 3  2018-02-17 00:00:00     2018-02-18 14:36:24            1.0
# 4  2017-04-21 00:00:00     2017-04-21 22:02:06            1.0
#
#                          product_id                         seller_id  ...  \
# 0  fd25ab760bfbba13c198fa3b4f1a0cd3  6d803cb79cc31c41c4c789a75933b3c7  ...
# 1  fd25ab760bfbba13c198fa3b4f1a0cd3  6d803cb79cc31c41c4c789a75933b3c7  ...
# 2  be0dbdc3d67d55727a65d4cd696ca73c  8e6d7754bc7e0f22c96d255ebda59eba  ...
# 3  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48  ...
# 4  52c80cedd4e90108bf4fa6a206ef6b03  a1043bafd471dff536d0c462352beb48  ...
#
#   freight_value   product_category_name  product_name_lenght  \
# 0         13.63           esporte_lazer                 42.0
# 1         13.63           esporte_lazer                 42.0
# 2          8.30  informatica_acessorios                 47.0
# 3         45.12  informatica_acessorios                 59.0
# 4         42.85      ferramentas_jardim                 33.0
#
#   product_description_lenght  product_photos_qty  product_weight_g  \
# 0                      858.0                 1.0            1300.0
# 1                      858.0                 1.0            1300.0
# 2                      493.0                 1.0             245.0
# 3                     1893.0                 1.0            6550.0
# 4                     2188.0                 2.0            7650.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               30.0               30.0              35.0
# 1               30.0               30.0              35.0
# 2               19.0               14.0              14.0
# 3               20.0               20.0              20.0
# 4               20.0               20.0              20.0
#
#    product_category_name_english
# 0                 sports_leisure
# 1                 sports_leisure
# 2          computers_accessories
# 3          computers_accessories
# 4                   garden_tools
#
# [5 rows x 22 columns]

# %%
review_count_df = review_df.groupby(by='product_category_name_english').agg({
    'order_id': 'nunique',
    'review_score': 'mean'
}, inplace=True)

review_count_df.rename(columns={
    'order_id': 'total_order',
    'review_score': 'mean_review_score'
}, inplace=True)

# %%
review_count_df.sort_values(by='mean_review_score', ascending=False).head()
# Out:
#                                total_order  mean_review_score
# product_category_name_english
# cds_dvds_musicals                       12           4.642857
# fashion_childrens_clothes                8           4.500000
# books_general_interest                 508           4.446266
# costruction_tools_tools                 94           4.444444
# flowers                                 28           4.419355

# %% [markdown]
# **<i>From the data above, it's clear that the best product based on reviews is: </i>**
# 1. `agro_industry_and_commerce`
# 2. `air_conditioning`
# 3. `art`
# 4. `arts_and_craftmanship`
# 5. `audio`

# %% [markdown]
# ## **Visualization & Explanatory Analysis**

# %% [markdown]
# ### **<I>Q1: Categories of products that are popular and those that are less popular based on the number of units sold</I>**

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
colors = ["#a1c9f4", "#ff9f9b", "#ff9f9b", "#ff9f9b", "#ff9f9b"]

sns.barplot(x='total_order', y='product_category_name_english', data=product_count_english_df.groupby('product_category_name_english').total_order.nunique().sort_values(ascending=False).reset_index().head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title('Produk yang Berkinerja Terbaik')
ax[0].tick_params(axis='y', labelsize=18)
ax[0].tick_params(axis='x', labelsize=18)

sns.barplot(x='total_order', y='product_category_name_english', data=product_count_english_df.groupby('product_category_name_english').total_order.nunique().sort_values(ascending=True).reset_index().head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')
ax[1].set_title('Produk yang Berkinerja Terburuk')
ax[1].tick_params(axis='y', labelsize=18)
ax[1].tick_params(axis='x', labelsize=18)

plt.suptitle('Produk yang Berkinerja Terbaik dan Terburuk Berdasarkan Jumlah Penjualan', fontsize=23)
plt.show()

# %% [markdown]
# _**The best-performing productk:**_
# 1. bed_bath_table
# 2. health_beauty
# 3. sports_leisure
# 4. computers_accessories
# 5. furniture_decor
#
# _**However, the worst-performing product:**_
# 1. security_and_services
# 2. fashion_childrens_clothes
# 3. cds_dvds_musicals
# 4. la_cuisine
# 5. arts_and_craftmanship

# %% [markdown]
# ### _**Q2: Categories of products with the highest average review scores**_

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
colors = ["#a1c9f4", "#ff9f9b", "#ff9f9b", "#ff9f9b", "#ff9f9b"]

sns.barplot(x='mean_review_score', y='product_category_name_english', data=review_count_df.reset_index().sort_values(by='mean_review_score', ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title('Produk yang Berkinerja Terbaik')
ax[0].tick_params(axis='y', labelsize=15)
ax[0].tick_params(axis='x', labelsize=15)

sns.barplot(x='mean_review_score', y='product_category_name_english', data=review_count_df.reset_index().sort_values(by='mean_review_score', ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')
ax[1].set_title('Produk yang Berkinerja Terburuk')
ax[1].tick_params(axis='y', labelsize=15)
ax[1].tick_params(axis='x', labelsize=15)

plt.suptitle('Produk yang Berkinerja Terbaik dan Terburuk Berdasarkan Penilaian Ulasan', fontsize=23)
plt.show()

# %% [markdown]
# ### _**Q3: How is the income during sales?**_

# %%
monthly_revenue_df = revenue_by_day_df.resample(rule='M', 
                                                on='order_approved_at').agg({
    'total_order': 'sum',
    'total_revenue': 'sum'
})
monthly_revenue_df.index = monthly_revenue_df.index.strftime('%Y-%m')
monthly_revenue_df = monthly_revenue_df.reset_index()

# Deleting the last month because the data is only available until the 3rd, not until the end of the month.
monthly_revenue_df = monthly_revenue_df[monthly_revenue_df['order_approved_at'] != monthly_revenue_df['order_approved_at'].max()]

# %%
plt.figure(figsize=(10,5))
plt.plot(monthly_revenue_df['order_approved_at'], 
         monthly_revenue_df['total_order'], 
         marker='s', color='c')
plt.title('Jumlah dari penjualan per bulan (2016/09 - 2018/07)')
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(monthly_revenue_df['order_approved_at'], 
         monthly_revenue_df['total_revenue'], 
         marker='s', color='c')
plt.title('Total Revenue per Month (2016/09 - 2018/07)')
plt.xticks(rotation=45, fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# <I>From the visualization above, we can learn that Total Revenue correlates directly with the total orders in that month. Therefore, as the total orders increase, total revenue also increases.</I>

# %% [markdown]
# # **SUMMARY**

# %% [markdown]
# _Question:_
#
# __1. Categories of products that are popular and those that are less popular based on the number of units sold__
#
# _Answer_
#
# _**The best-performing product:**_
# 1. bed_bath_table
# 2. health_beauty
# 3. sports_leisure
# 4. computers_accessories
# 5. furniture_decor
#
# _**However, the worst-performing product:**_
# 1. security_and_services
# 2. fashion_childrens_clothes
# 3. cds_dvds_musicals
# 4. la_cuisine
# 5. arts_and_craftmanship
#
#
# __2. Categories of products with the highest average review scores__
#
# _Answer_
#
# _In terms of reviews, the best category of products is `cds_dvds_musicals`, while the worst category is `security_and_services`._
#
# __3. How is the income during sales?__
#
# _Answer_
#
# _The revenue over the past two years has been very good, with a significant increase from `2016/2` to `2017/11`._
